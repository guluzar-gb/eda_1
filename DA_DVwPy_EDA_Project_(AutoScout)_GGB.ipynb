# %% [markdown]
# <a href="https://colab.research.google.com/github/guluzar-gb/eda_1/blob/main/DA_DVwPy_EDA_Project_(AutoScout)_GGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib as mpl

# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %%
from zipfile import ZipFile

with ZipFile("as24_cars.zip", "r") as data:
    data.extractall()

df_raw = pd.read_json("as24_cars.json")
df_original=df_raw.copy()

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# STEP-1
# >>>>
# >>>Look into the data

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
# ...

# %%
df_raw.shape
# Out:
# (29480, 58)

# %%
df_raw.head().T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
dtypes = df_raw.dtypes.to_frame(name='dtypes')
dtypes
# Out:
#                             dtypes
# make_model                  object
# short_description           object
# make                        object
# model                       object
# location                    object
# price                       object
# Body type                   object
# Type                        object
# Doors                       object
# Country version             object
# Offer number                object
# Warranty                    object
# Mileage                     object
# First registration          object
# Gearbox                     object
# Fuel type                   object
# Colour                      object
# Paint                       object
# desc                        object
# seller                      object
# Seats                       object
# Power                       object
# Engine size                 object
# Gears                       object
# CO₂-emissions               object
# Manufacturer colour         object
# ...

# %%
#counting non-null counts of the columns and saving the result as a dataframe.
nonnull = pd.DataFrame(df_raw[df_raw.notnull()].count(), columns=['notnull'])
nonnull.style.highlight_min(color = '#97b4FF')
# Out:
# <style type="text/css">
# #T_bcc0f_row57_col0 {
#   background-color: #97b4FF;
# }
# </style>
# <table id="T_bcc0f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcc0f_level0_col0" class="col_heading level0 col0" >notnull</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcc0f_level0_row0" class="row_heading level0 row0" >make_model</th>
#       <td id="T_bcc0f_row0_col0" class="data row0 col0" >28630</td>
#     </tr>
#     <tr>
#       <th id="T_bcc0f_level0_row1" class="row_heading level0 row1" >short_description</th>
#       <td id="T_bcc0f_row1_col0" class="data row1 col0" >28630</td>
#     </tr>
#     <tr>
#       <th id="T_bcc0f_level0_row2" class="row_heading level0 row2" >make</th>
#       <td id="T_bcc0f_row2_col0" class="data row2 col0" >28630</td>
#     </tr>
#     <tr>
#       <th id="T_bcc0f_level0_row3" class="row_heading level0 row3" >model</th>
# ...

# %%
#finding %non-null  of the columns
nonnull_percent = nonnull/df_raw.shape[0]*100
nonnull_percent
# Out:
#                              notnull
# make_model                 97.116689
# short_description          97.116689
# make                       97.116689
# model                      97.116689
# location                   97.116689
# price                      97.116689
# Body type                  97.116689
# Type                       97.116689
# Doors                      95.898915
# Country version            57.289688
# Offer number               78.358209
# Warranty                   53.541384
# Mileage                    97.113297
# First registration         97.109905
# Gearbox                    96.275441
# Fuel type                  91.054953
# Colour                     91.268657
# Paint                      49.168928
# desc                       95.139077
# seller                     97.116689
# Seats                      86.516282
# Power                      95.176391
# Engine size                92.357531
# Gears                      64.294437
# ...

# %%
#finding the sum of missing values for each column  #total raw=29480
df_raw.isna().sum()
# Out:
# make_model                     850
# short_description              850
# make                           850
# model                          850
# location                       850
# price                          850
# Body type                      850
# Type                           850
# Doors                         1209
# Country version              12591
# Offer number                  6380
# Warranty                     13696
# Mileage                        851
# First registration             852
# Gearbox                       1098
# Fuel type                     2637
# Colour                        2574
# Paint                        14985
# desc                          1433
# seller                         850
# Seats                         3975
# Power                         1422
# Engine size                   2253
# Gears                        10526
# CO₂-emissions                10886
# Manufacturer colour           7693
# Drivetrain                   12587
# ...

# %%
#finding the percentage of missing values in each column
missing_percentages = pd.DataFrame(round((df_raw.isna().sum() / len(df_raw)) * 100,2), columns=["null_percentage"])
#or df_raw.isnull().mean() --->missing value distribution
#instead of len(df_raw) ----df.shape[0] gives number of rows
missing_percentages.style.highlight_between(left = 65,right =100)
# Out:
# <style type="text/css">
# #T_ed49c_row34_col0, #T_ed49c_row36_col0, #T_ed49c_row40_col0, #T_ed49c_row43_col0, #T_ed49c_row45_col0, #T_ed49c_row46_col0, #T_ed49c_row47_col0, #T_ed49c_row48_col0, #T_ed49c_row49_col0, #T_ed49c_row50_col0, #T_ed49c_row51_col0, #T_ed49c_row52_col0, #T_ed49c_row53_col0, #T_ed49c_row54_col0, #T_ed49c_row55_col0, #T_ed49c_row56_col0, #T_ed49c_row57_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_ed49c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed49c_level0_col0" class="col_heading level0 col0" >null_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed49c_level0_row0" class="row_heading level0 row0" >make_model</th>
#       <td id="T_ed49c_row0_col0" class="data row0 col0" >2.880000</td>
#     </tr>
#     <tr>
#       <th id="T_ed49c_level0_row1" class="row_heading level0 row1" >short_description</th>
# ...

# %%
#null_values=pd.DataFrame(df_raw.isna().sum(), columns=['null_values'])
#null_values.style.highlight_between(left = 1500,right =3000)

# %%
#finding how many columns have null values more than 65%  #I will drop 17 columns
missing_percentages[missing_percentages.null_percentage>65].count()
# Out:
# null_percentage    17
# dtype: int64

# %%
#Find out the unique counts of the columns and save the result as a dataframe.
len(df_raw.make.unique())
#nunq = df_raw.nunique().to_frame(name= 'nunique') raising error due to list type of the columns
#nunq
# Out:
# 14

# %% [markdown]
# potential problems
# >>>
# -missing values
# >>>
# -words and numbers
# >>>
# -multiple distinct words joined together
# >>>
# -trailing whitespaces
# >>>
# -improper text format(use regex)
# >>>
# column names with special char like co2
# >>>
# i can remove short description and location columns
# >>>
# turn nan to true NaN

# %%
#Lowercase all column names
df_raw.columns = df_raw.columns.str.upper()
df_raw.columns = [i.lower() for i in df_raw.columns]

# %%
df_raw.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body type', 'type', 'doors', 'country version', 'offer number',
#        'warranty', 'mileage', 'first registration', 'gearbox', 'fuel type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine size',
#        'gears', 'co₂-emissions', 'manufacturer colour', 'drivetrain',
#        'cylinders', 'fuel consumption', '\ncomfort & convenience\n',
#        '\nentertainment & media\n', '\nsafety & security\n', '\nextras\n',
#        'empty weight', 'model code', 'general inspection', 'last service',
#        'full service history', 'non-smoker vehicle', 'emission class',
#        'emissions sticker', 'upholstery colour', 'upholstery',
#        'production date', 'previous owner', 'other fuel types',
#        'power consumption', 'energy efficiency class', 'co₂-efficiency',
#        'fuel consumption (wltp)', 'co₂-emissions (wltp)', 'available from',
# ...

# %%
df_raw.make=df_raw.make.str.strip("\n")
df_raw.make.unique()
# Out:
# array(['Mercedes-Benz', nan, 'Opel', 'Renault', 'Peugeot', 'Fiat', 'SEAT',
#        'Skoda', 'Dacia', 'Toyota', 'Nissan', 'Ford', 'Hyundai', 'Volvo'],
#       dtype=object)

# %%
df_raw.location=df_raw.location.apply(lambda x: x.split(",")[-1] if type(x)== str else np.nan)
df_raw.location.unique()
# Out:
# array([' ES', ' DE', ' BE', ' AT', ' NL', ' FR', ' IT', nan, ' LU', ' DK',
#        ' EE', ' BG'], dtype=object)

# %%
df_raw.mileage=df_raw.mileage.str.strip(" km").str.replace(",", "")
df_raw.mileage
# Out:
# 0        120200
# 1          5000
# 2         18900
# 3         18995
# 4        197000
#           ...
# 29475    145000
# 29476     96000
# 29477     94343
# 29478    230047
# 29479       NaN
# Name: mileage, Length: 29480, dtype: object

# %%
df_raw.rename(columns={df_raw.columns[12]: "mileage_km"}, inplace=True)

# %%
df_raw["first registration"].unique()
# Out:
# array(['06/2016', '06/2022', '07/2020', '01/2020', '09/2015', '08/2005',
#        '07/2018', '10/2019', '06/2019', '08/2018', '04/2015', '01/2016',
#        '10/2013', '05/2016', '04/2010', '03/2021', '09/2018', '08/2020',
#        '01/2019', '12/2021', '03/2014', '10/2014', '07/2005', '05/2020',
#        '09/2016', '04/2017', '04/2019', '05/2014', '07/2019', '01/2021',
#        '08/2011', '08/2019', '02/2020', '03/2013', '10/2020', '06/2020',
#        '12/2020', '10/2018', '05/2021', '05/2006', '11/2017', '09/2020',
#        '07/2021', '07/2016', '11/2019', '03/2018', '03/2012', '03/2008',
#        '06/2005', '01/2022', '02/2019', '02/2015', '02/2021', '09/1986',
#        '07/2022', '02/2022', '04/2021', '10/2021', '03/2015', '01/2017',
#        '08/2017', '12/2016', '05/2022', '05/2019', '09/2013', '11/2015',
#        '08/2021', '11/2021', '02/2014', '11/2016', '04/2014', '08/2012',
#        '03/2016', '12/2017', '11/2006', '11/2012', '03/2019', '12/2014',
# ...

# %%
# Convert the column to datetime data type while handling NaN values
df_raw['first registration'] = pd.to_datetime(df_raw['first registration'], errors='coerce')

# Extract the year values from the datetime column
df_raw['first registration'] = df_raw['first registration'].dt.year

# %%
cols_startswith_bracket = [col for col in df_raw.columns if any(df_raw[col].apply(lambda x: str(x).startswith('[')))]
cols_startswith_bracket
s1=pd.DataFrame(cols_startswith_bracket, columns=['cols_startswith_bracket'])

# %%
#to understand which columns in s1 is not important
#df_bracket_null = pd.merge(s1, missing_percentages, on="cols_startswith_bracket")
#df_bracket_null
#ERROR

# %%
#df_raw.columns.get_loc("\ncomfort & convenience\n")
column_numbers = [df_raw.columns.get_loc(i) for i in ["\ncomfort & convenience\n", "\nentertainment & media\n", "\nsafety & security\n", "\nextras\n"]]
column_numbers
# Out:
# [29, 30, 31, 32]

# %%
#def clean_col_name(x):
#        return replace('\n', '').replace(' & ','_')

# %%
# clean up the column name
comfort_convenience = df_raw.columns[29].replace('\n', '').replace(' & ','_')
df_raw.rename(columns={df_raw.columns[29]: "comfort_convenience"}, inplace=True)

# %%
entertainment_media = df_raw.columns[30].replace('\n', '').replace(' & ','_')
df_raw.rename(columns={df_raw.columns[30]: "entertainment_media"}, inplace=True)
df_raw.columns[30]
# Out:
# 'entertainment_media'

# %%
safety_security = df_raw.columns[31].replace('\n', '').replace(' & ','_')
df_raw.rename(columns={df_raw.columns[31]: "safety_security"}, inplace=True)
df_raw.columns[31]
# Out:
# 'safety_security'

# %%
extras = df_raw.columns[32].replace('\n', '')
df_raw.rename(columns={df_raw.columns[32]: extras}, inplace=True)
df_raw.columns[32]
# Out:
# 'extras'

# %%
df_raw.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body type', 'type', 'doors', 'country version', 'offer number',
#        'warranty', 'mileage_km', 'first registration', 'gearbox', 'fuel type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine size',
#        'gears', 'co₂-emissions', 'manufacturer colour', 'drivetrain',
#        'cylinders', 'fuel consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty weight',
#        'model code', 'general inspection', 'last service',
#        'full service history', 'non-smoker vehicle', 'emission class',
#        'emissions sticker', 'upholstery colour', 'upholstery',
#        'production date', 'previous owner', 'other fuel types',
#        'power consumption', 'energy efficiency class', 'co₂-efficiency',
#        'fuel consumption (wltp)', 'co₂-emissions (wltp)', 'available from',
# ...

# %%
df_raw.model=df_raw.model.str[0].str.strip("\[]\n, ]")   #apply(lambda x: ''.join(x)).str.replace(r'[\n, ]', '').str.strip()
df_raw.model
#or df_raw['model'].str[0].astype(str).str.replace(r'[\n\[\]\ \,]', '').str.strip()
# Out:
# 0           A 160
# 1         EQE 350
# 2        A 45 AMG
# 3        A 35 AMG
# 4        A 45 AMG
#            ...
# 29475         S40
# 29476         C30
# 29477         S90
# 29478         S80
# 29479         NaN
# Name: model, Length: 29480, dtype: object

# %%
df_raw.model.unique()
# Out:
# array(['A 160', 'EQE 350', 'A 45 AMG', 'A 35 AMG', 'C 160', 'CLA 180',
#        'A 220', 'A 200', 'A 250', 'A 180', 'GLC 220', 'E 220', 'B 200',
#        'A 150', 'V 220', 'AMG GT', 'E 300', 'EQS', 'A 140', '', 'CL',
#        'B 180', 'GLB 200', 'E 350', 'CLA 200', '280', 'GLA 180', 'Viano',
#        'E 53 AMG', 'SLK 200', 'GLE 350', '220', 'SL 500', 'E 400',
#        'SLC 43 AMG', 'SL 350', 'SLC 250', 'SLK 350', 'SLS', 'CLK 200',
#        'C 400', 'SL 65 AMG', 'C 43 AMG', 'C 63 AMG', 'SLK 250', '500',
#        'SLK 300', 'SLC 200', 'SLK 55 AMG', 'S 63 AMG', '230', 'E 500',
#        'SLK', 'SL 55 AMG', 'CLK 55 AMG', 'C 300', 'SLK 280', 'E 450',
#        'SLC 180', 'C 200', 'E 200', 'SL 63 AMG', 'SL 300', 'S 560',
#        'C 180', 'C 250', 'C 220', 'E 250', 'SL 560', 'SLK 230', 'SL 280',
#        'SL 380', 'SL 600', 'G 500', '190', '250', 'CLK 350', 'SLC 300',
#        'G 320', 'S 500', 'SL 320', 'SLR', 'SL 400', 'CLK 280', 'SL 450',
# ...

# %%
# extracting num values in price column (€ 16,950.-)
df_raw["price"]=df_raw["price"].str.extract(r"([\d,]+)\s*", expand=False)

#to remove the commas
df_raw["price"] = df_raw["price"].str.replace(",", "")
df_raw["price"]
# Out:
# 0        16950
# 1        80900
# 2        69900
# 3        46990
# 4        16800
#          ...
# 29475     5499
# 29476     7300
# 29477    29900
# 29478     4440
# 29479      NaN
# Name: price, Length: 29480, dtype: object

# %%
df_raw["price"].astype(float).sort_values()
# Out:
# 5876     490.0
# 5540     500.0
# 20045    500.0
# 17883    590.0
# 5314     600.0
#          ...
# 29419      NaN
# 29445      NaN
# 29451      NaN
# 29473      NaN
# 29479      NaN
# Name: price, Length: 29480, dtype: float64

# %%
df_raw = df_raw.rename(columns={"price": "price_EUR"})
df_raw.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location',
#        'price_EUR', 'body type', 'type', 'doors', 'country version',
#        'offer number', 'warranty', 'mileage_km', 'first registration',
#        'gearbox', 'fuel type', 'colour', 'paint', 'desc', 'seller', 'seats',
#        'power', 'engine size', 'gears', 'co₂-emissions', 'manufacturer colour',
#        'drivetrain', 'cylinders', 'fuel consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty weight',
#        'model code', 'general inspection', 'last service',
#        'full service history', 'non-smoker vehicle', 'emission class',
#        'emissions sticker', 'upholstery colour', 'upholstery',
#        'production date', 'previous owner', 'other fuel types',
#        'power consumption', 'energy efficiency class', 'co₂-efficiency',
#        'fuel consumption (wltp)', 'co₂-emissions (wltp)', 'available from',
# ...

# %%
#df1= [i.str[0].str.strip("\[]\n, ]") for i in df_raw.columns if any(df_raw[i].apply(lambda x: str(x).startswith('[')))]

# %%
#def col_trim():
#    return [i.str[0].str.strip("\[]\n, ]") for i in df_raw.columns]

# %%
#To apply multiple columns
#df1=df_raw[['warranty', 'seats']].apply(lambda x: x[0].str.strip("\[]\n]"))

# %%
df_raw["type"]=df_raw["type"].str[0].str.strip("\[]\n, ]")

# %%
df_raw["type"].unique() #why there is no unused
# Out:
# array(['Used', 'Pre-registered', 'Demonstration', "Employee's car", nan],
#       dtype=object)

# %%
df_raw["body type"]=df_raw["body type"].str[0].str.strip("\[]\n, ]")

# %%
df_raw["body type"].unique()
# Out:
# array(['Compact', 'Convertible', 'Coupe', 'Off-Road/Pick-up',
#        'Station wagon', nan, 'Sedan'], dtype=object)

# %%
df_raw["doors"]=df_raw["doors"].str[0].str.strip("\[]\n, ]")
df_raw["doors"].unique()
# Out:
# array(['5', '4', '3', '2', nan, '1', '6'], dtype=object)

# %%
df_raw["country version"]=df_raw["country version"].str[0].str.strip("\[]\n, ]") #not so important
df_raw["country version"].unique()
# Out:
# array(['Spain', 'Germany', nan, 'Belgium', 'Austria', 'France',
#        'Netherlands', 'Italy', 'European Union', 'Luxembourg', 'Slovenia',
#        'Poland', 'Hungary', 'Japan', 'Switzerland', 'Romania', 'Denmark',
#        'Czechia', 'Slovakia', 'Croatia', 'Bulgaria', 'United States',
#        'Sweden', 'Malta', 'Canada', 'Mexico'], dtype=object)

# %%
df_raw["offer number"]=df_raw["offer number"].str[0].str.strip("\[]\n, ]")
df_raw["offer number"].unique()
# Out:
# array(['7468157', '7054863', '7410454', ..., '09-PF-XS', '2791',
#        '43-JR-LR'], dtype=object)

# %%
df_raw["warranty"]=df_raw["warranty"].str[0].str.strip("\[]\n, ]")
df_raw["warranty"].unique()
# Out:
# array(['24 months', '12 months', nan, 'Yes', '48 months', '6 months',
#        '3 months', '8 months', '36 months', '122 months', '0 months',
#        '60 months', '22 months', '23 months', '18 months', '28 months',
#        '17 months', '19 months', '21 months', '72 months', '11 months',
#        '7 months', '1 months', '10 months', '30 months', '13 months',
#        '90 months', '16 months', '9 months', '84 months', '14 months',
#        '15 months', '47 months', '20 months', '27 months', '34 months',
#        '33 months', '31 months', '26 months', '32 months', '99 months',
#        '50 months', '35 months', '110 months', '142 months', '80 months',
#        '65 months', '43 months', '117 months', '58 months', '46 months',
#        '2 months', '45 months', '53 months', '52 months', '39 months',
#        '25 months', '57 months', '37 months', '49 months', '55 months',
#        '51 months', '29 months', '42 months', '44 months', '4 months'],
#       dtype=object)

# %%
df_raw.warranty=df_raw.warranty.str.strip("\'months ")
df_raw.warranty.unique()
# Out:
# array(['24', '12', nan, 'Ye', '48', '6', '3', '8', '36', '122', '0', '60',
#        '22', '23', '18', '28', '17', '19', '21', '72', '11', '7', '1',
#        '10', '30', '13', '90', '16', '9', '84', '14', '15', '47', '20',
#        '27', '34', '33', '31', '26', '32', '99', '50', '35', '110', '142',
#        '80', '65', '43', '117', '58', '46', '2', '45', '53', '52', '39',
#        '25', '57', '37', '49', '55', '51', '29', '42', '44', '4'],
#       dtype=object)

# %%
df_raw.warranty=df_raw.warranty.apply(lambda x: 'Yes' if x == 'Ye' else x)
df_raw.warranty.unique()
#FILL the "yes" value
# Out:
# array(['24', '12', nan, 'Yes', '48', '6', '3', '8', '36', '122', '0',
#        '60', '22', '23', '18', '28', '17', '19', '21', '72', '11', '7',
#        '1', '10', '30', '13', '90', '16', '9', '84', '14', '15', '47',
#        '20', '27', '34', '33', '31', '26', '32', '99', '50', '35', '110',
#        '142', '80', '65', '43', '117', '58', '46', '2', '45', '53', '52',
#        '39', '25', '57', '37', '49', '55', '51', '29', '42', '44', '4'],
#       dtype=object)

# %%
#Changing the yes values with min warranty time which is 1
#df_raw.warranty=df_raw.warranty.apply(lambda x: '1' if x == 'Yes' else x)
#df_raw.warranty.unique()

# %%
df_raw.warranty.isnull().count()
# Out:
# 29480

# %%
df_raw.warranty=df_raw.warranty.apply(lambda x: np.nan if x == '0' else x)

# %%
df_raw.warranty.isnull().count()
# Out:
# 29480

# %%
df_raw = df_raw.rename(columns={"warranty": "warranty_months"})
df_raw.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location',
#        'price_EUR', 'body type', 'type', 'doors', 'country version',
#        'offer number', 'warranty_months', 'mileage_km', 'first registration',
#        'gearbox', 'fuel type', 'colour', 'paint', 'desc', 'seller', 'seats',
#        'power', 'engine size', 'gears', 'co₂-emissions', 'manufacturer colour',
#        'drivetrain', 'cylinders', 'fuel consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty weight',
#        'model code', 'general inspection', 'last service',
#        'full service history', 'non-smoker vehicle', 'emission class',
#        'emissions sticker', 'upholstery colour', 'upholstery',
#        'production date', 'previous owner', 'other fuel types',
#        'power consumption', 'energy efficiency class', 'co₂-efficiency',
#        'fuel consumption (wltp)', 'co₂-emissions (wltp)', 'available from',
# ...

# %%
#df_raw.loc[df_raw.warranty.str.startswith("0"), "warranty"] = np.nan
#I have to remove the nans first

# %%
df_raw.groupby(["fuel type"]).size()
# Out:
# fuel type
# Biogas                                                                                                   1
# CNG                                                                                                     87
# CNG (Particle filter)                                                                                    8
# Diesel                                                                                                5911
# Diesel (Particle filter)                                                                              2816
# Domestic gas H                                                                                          24
# Domestic gas H / Super E10 95 / Super Plus E10 98 / Super 95 / Super Plus 98 / Domestic gas L            1
# Domestic gas L                                                                                          10
# Domestic gas L (Particle filter)                                                                         2
# ...

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "LPG_and_gasoline"  if ("Liquid petroleum gas (LPG)" in str(x)) or ("Domestic" in str(x)) and ("Super" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "gasoline"  if ("Benzine" in str(x)) and ("Regular" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "gasoline_and_ethanol"  if ("Super" in str(x)) and ("Ethanol" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "gasoline"  if ("Super" in str(x)) and ("Particle" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "gasoline"  if ("Super" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "LPG"  if ("Domestic" in str(x)) or (("LPG" in str(x)) and ("Particle" in str(x))) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "gasoline"  if ("Gasoline" in str(x)) or (("Gasoline" in str(x)) and ("Particle" in str(x))) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "CNG"  if ("CNG" in str(x)) and ("Particle" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "diesel"  if ("Diesel" in str(x)) and ("Particle" in str(x)) or ("Diesel" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "electric"  if ("Electric" in str(x)) and ("Particle" in str(x)) or ("Electric" in str(x)) else x)

# %%
df_raw["fuel type"]=df_raw["fuel type"].apply(lambda x: "others"  if ("Others" in str(x)) and ("Particle" in str(x)) or ("Others" in str(x)) else x)

# %%
df_raw.groupby(["fuel type"]).size()
# Out:
# fuel type
# Biogas                      1
# CNG                        95
# Ethanol                     3
# Hydrogen                    3
# LPG                       113
# LPG_and_gasoline          169
# diesel                   8727
# electric                  188
# gasoline                17330
# gasoline_and_ethanol        1
# others                    213
# dtype: int64

# %%
df_raw["gearbox"]=df_raw["gearbox"].str[0].str.strip("\[]\n, ]")
df_raw["gearbox"].unique()
# Out:
# array(['Manual', 'Automatic', nan, 'Semi-automatic'], dtype=object)

# %%
df_raw["desc"]=df_raw["desc"].str[0].str.strip("\[]\n, ]")
df_raw["desc"].unique()
# Out:
# array(['', 'Gris MANUFAKTUR mountaingrau magno', 'Sonderausstattung:',
#        ...,
#        'Een goed rijdende auto met APK + NAP + Elektrische ramen + elektrische spiegels + lichtmetalen velgen + automaat',
#        '*** VOLVO C30 2011 TRES PROPRE EN PARFAIT ETAT ***',
#        'YOUNGTIMER !'], dtype=object)

# %%
df_raw["seats"]=df_raw["seats"].str[0].str.strip("\[]\n, ]")

# %%
df_raw["seats"].unique() #17 could be outlier
# Out:
# array([nan, '5', '4', '2', '9', '7', '6', '8', '3', '17', '0', '1'],
#       dtype=object)

# %%
#def clean_list(x):
#    if type(x)==list:
#       return x[0].split(",")[1]
#    else:
#        return np.nan

# %%
df_raw["power"]=df_raw["power"].str[0].str.strip("\[]\n, ]")
df_raw["power"].unique()
# Out:
# array([nan, '215 kW (292 hp)', '310 kW (421 hp)', '225 kW (306 hp)',
#        '100 kW (136 hp)', '90 kW (122 hp)', '140 kW (190 hp)',
#        '102 kW (139 hp)', '66 kW (90 hp)', '280 kW (381 hp)',
#        '155 kW (211 hp)', '85 kW (116 hp)', '80 kW (109 hp)',
#        '118 kW (160 hp)', '120 kW (163 hp)', '143 kW (194 hp)',
#        '265 kW (360 hp)', '160 kW (218 hp)', '125 kW (170 hp)',
#        '110 kW (150 hp)', '173 kW (235 hp)', '70 kW (95 hp)',
#        '410 kW (557 hp)', '270 kW (367 hp)', '470 kW (639 hp)',
#        '320 kW (435 hp)', '385 kW (523 hp)', '271 kW (368 hp)',
#        '266 kW (362 hp)', '202 kW (275 hp)', '375 kW (510 hp)',
#        '279 kW (379 hp)', '165 kW (224 hp)', '471 kW (640 hp)',
#        '75 kW (102 hp)', '132 kW (179 hp)', '130 kW (177 hp)',
#        '121 kW (165 hp)', '115 kW (156 hp)', '228 kW (310 hp)',
#        '67 kW (91 hp)', '79 kW (107 hp)', '101 kW (137 hp)',
#        '142 kW (193 hp)', '112 kW (152 hp)', '122 kW (166 hp)',
# ...

# %%
# extracting values infront of the hp from 123 kW (9,80 hp)
df_raw["power"]=df_raw["power"].str.extract(r"\(([\d,]+)\s*hp\)", expand=False)

#to remove the commas
df_raw["power"] = df_raw["power"].str.replace(",", "")
df_raw["power"].unique()
#The expand=False parameter ensures that the result is returned as a series instead of a dataframe.
# Out:
# array([nan, '292', '421', '306', '136', '122', '190', '139', '90', '381',
#        '211', '116', '109', '160', '163', '194', '360', '218', '170',
#        '150', '235', '95', '557', '367', '639', '435', '523', '368',
#        '362', '275', '510', '379', '224', '640', '102', '179', '177',
#        '165', '156', '310', '91', '107', '137', '193', '152', '166',
#        '118', '110', '265', '185', '140', '184', '320', '476', '340',
#        '333', '204', '272', '571', '387', '530', '612', '522', '390',
#        '315', '245', '326', '231', '252', '585', '517', '462', '500',
#        '330', '469', '455', '238', '258', '188', '197', '158', '286',
#        '296', '105', '525', '457', '394', '556', '276', '201', '199',
#        '470', '86', '106', '230', '487', '481', '408', '299', '389',
#        '730', '220', '200', '799', '630', '143', '489', '544', '250',
#        '507', '449', '135', '228', '189', '658', '401', '239', '209',
# ...

# %%
#renaming the column power to power_hp
df_raw = df_raw.rename(columns={"power": "power_hp"})
df_raw.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location',
#        'price_EUR', 'body type', 'type', 'doors', 'country version',
#        'offer number', 'warranty_months', 'mileage_km', 'first registration',
#        'gearbox', 'fuel type', 'colour', 'paint', 'desc', 'seller', 'seats',
#        'power_hp', 'engine size', 'gears', 'co₂-emissions',
#        'manufacturer colour', 'drivetrain', 'cylinders', 'fuel consumption',
#        'comfort_convenience', 'entertainment_media', 'safety_security',
#        'extras', 'empty weight', 'model code', 'general inspection',
#        'last service', 'full service history', 'non-smoker vehicle',
#        'emission class', 'emissions sticker', 'upholstery colour',
#        'upholstery', 'production date', 'previous owner', 'other fuel types',
#        'power consumption', 'energy efficiency class', 'co₂-efficiency',
#        'fuel consumption (wltp)', 'co₂-emissions (wltp)', 'available from',
# ...

# %%
df_raw["engine size"]=df_raw["engine size"].str[0].str.strip("\[]\n, ]")
df_raw["engine size"].unique()
# Out:
# array([nan, '1 cc', '1,991 cc', '2,143 cc', '1,799 cc', '1,461 cc',
#        '1,332 cc', '1,950 cc', '2,035 cc', '1,595 cc', '1,699 cc',
#        '1,796 cc', '1,498 cc', '2,034 cc', '3,982 cc', '300 cc',
#        '2,999 cc', '1,337 cc', '1,500 cc', '1,333 cc', '1,900 cc',
#        '1,596 cc', '1,300 cc', '2,000 cc', '2,746 cc', '4,973 cc',
#        '2,925 cc', '2,996 cc', '3,498 cc', '6,208 cc', '5,461 cc',
#        '5,980 cc', '5,981 cc', '3,724 cc', '2,987 cc', '2,290 cc',
#        '5,439 cc', '2,997 cc', '4,663 cc', '3,000 cc', '1,497 cc',
#        '2,306 cc', '5,600 cc', '2,962 cc', '2,295 cc', '1,597 cc',
#        '2,717 cc', '2,966 cc', '3,793 cc', '1,998 cc', '1,993 cc',
#        '2,799 cc', '5,513 cc', '4,996 cc', '4,966 cc', '2,932 cc',
#        '2,960 cc', '5,987 cc', '2,748 cc', '6,300 cc', '6,209 cc',
#        '1,598 cc', '19,194 cc', '3,200 cc', '2,597 cc', '2,200 cc',
#        '1,795 cc', '3,199 cc', '2,276 cc', '2,180 cc', '4,489 cc',
# ...

# %%
df_raw["engine size"]=df_raw["engine size"].str.rstrip(" cc").str.replace(",", "")
df_raw["engine size"].unique()
#the paosisble minimum value should be 49 cc. Make NaN below that value
# Out:
# array([nan, '1', '1991', '2143', '1799', '1461', '1332', '1950', '2035',
#        '1595', '1699', '1796', '1498', '2034', '3982', '300', '2999',
#        '1337', '1500', '1333', '1900', '1596', '1300', '2000', '2746',
#        '4973', '2925', '2996', '3498', '6208', '5461', '5980', '5981',
#        '3724', '2987', '2290', '5439', '2997', '4663', '3000', '1497',
#        '2306', '5600', '2962', '2295', '1597', '2717', '2966', '3793',
#        '1998', '1993', '2799', '5513', '4996', '4966', '2932', '2960',
#        '5987', '2748', '6300', '6209', '1598', '19194', '3200', '2597',
#        '2200', '1795', '3199', '2276', '2180', '4489', '2199', '5786',
#        '2685', '3459', '2148', '2967', '3996', '3606', '0', '2297',
#        '2298', '2299', '1995', '2985', '2998', '1999', '2', '1992',
#        '1496', '2100', '1600', '4664', '2149', '2145', '2497', '2398',
#        '4146', '2548', '1248', '1229', '1199', '1686', '1398', '999',
# ...

# %%
#converting string 0 to NaN
df_raw["engine size"].apply(lambda x: np.nan if x=="0" else x)
df_raw= df_raw.rename(columns={"engine size": "engine_size_cc"})

# %%
df_raw["gears"]=df_raw["gears"].str[0].str.strip("\[]\n, ]")
df_raw["gears"].unique()
# Out:
# array([nan, '9', '8', '7', '6', '1', '5', '4', '3', '0', '2', '10'],
#       dtype=object)

# %%
df_raw["empty weight"]=df_raw["empty weight"].str[0].str.strip("\[]\n, ]").str.rstrip(" kg").str.replace(",", "")
df_raw["empty weight"].unique()
# Out:
# array([nan, '1545', '1465', ..., '1887', '1517', '1391'], dtype=object)

# %%
df_raw.rename(columns={df_raw.columns[33]: "empty_weight_kg"}, inplace=True)

# %%
df_raw.columns[33]
# Out:
# 'empty_weight_kg'

# %%
#df_raw["manufacturer colour"]=df_raw["manufacturer colour"].str[0].str.strip("\[]\n, ]")  #ERROR
#df_raw["manufacturer colour"].unique()

# %%
df_raw["drivetrain"]=df_raw["drivetrain"].str[0].str.strip("\[]\n, ]")
df_raw["drivetrain"].unique()
# Out:
# array([nan, '4WD', 'Rear', 'Front'], dtype=object)

# %%
df_raw["cylinders"]=df_raw["cylinders"].str[0].str.strip("\[]\n, ]")
df_raw["cylinders"].unique()

# Possible range is 2-16
# Out:
# array([nan, '4', '8', '6', '0', '12', '5', '1', '3', '7', '26', '2', '16'],
#       dtype=object)

# %%
#converting string 0 to NaN
df_raw["cylinders"]=df_raw["cylinders"].apply(lambda x: np.nan if x=="0" else x)
df_raw["cylinders"].unique()
# Out:
# array([nan, '4', '8', '6', '12', '5', '1', '3', '7', '26', '2', '16'],
#       dtype=object)

# %%
df_raw["fuel consumption"]=df_raw["fuel consumption"].str[0].str.strip("\[]\n, ]")
df_raw["fuel consumption"].unique()
# Out:
# array([nan])

# %%
type(df_raw["production date"][778])
# Out:
# numpy.float64

# %%
df_raw["production date"][778].astype(int)
# Out:
# 1962

# %%
#df_raw["production date"].apply(lambda x: x.astype(int) if x!= np.nan else x).unique()

# %%
df_raw["production date"].unique()
# Out:
# array([  nan, 2019., 2021., 2018., 2014., 2011., 2020., 2022., 2017.,
#        2016., 2013., 2008., 2002., 1991., 2010., 2006., 2012., 1999.,
#        2015., 1997., 2004., 1996., 1962., 2005., 2003., 2007., 1993.,
#        1994., 2009., 2001., 1985., 1970., 1990., 1998., 1981., 1995.,
#        1973., 2000., 1978., 1987., 1982., 1988., 1966., 1965., 1967.,
#        1961., 1968., 1954., 1969., 1976.])

# %%
df_raw["emission class"].unique()
# Out:
# array([nan, 'Euro 4', 'Euro 6', 'Euro 6d-TEMP', 'Euro 5', 'Euro 6d',
#        'Euro 6c', 'Euro 3', 'Euro 2', 'Euro 1'], dtype=object)

# %%
df_raw["comfort_convenience"].sample(5)
#I can extract Armrest, Navigation system, Parking asist system camera, Driver-side airbag
# Out:
# 5138                                                                                                                                                                             [Air conditioning, Cruise control, Multi-function steering wheel, Power windows]
# 16559                         [Air conditioning, Automatic climate control, Cruise control, Multi-function steering wheel, Parking assist system sensors front, Parking assist system sensors rear, Power windows, Rain sensor, Split rear seats, Tinted windows]
# 13973    [Air conditioning, Armrest, Automatic climate control, Cruise control, Electrical side mirrors, Leather steering wheel, Light sensor, Multi-function steering wheel, Navigation system, Parking assist system sensors rear, Power windows, Seat heating]
# ...

# %%
df_raw["safety_security"].sample(3)  #contains airbag should be important
# Out:
# 14915    [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Emergency brake assistant, Fog lights, Head airbag, Immobilizer, Isofix, LED Daytime Running Lights, LED Headlights, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system]
# 11251                                                                                                                                                                                                                                                                                                             NaN
# 25992                                                                                                                                                             [ABS, Central door lock, Driver-side airbag, Electronic stability control, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag]
# Name: safety_security, dtype: object

# %%
df_raw["safety_security"]
# Out:
# 0                                                                                                                                                                                                                                                                          NaN
# 1                                                                                                                                                                                                                                                                          NaN
# 2                                                                                                                                                                                                                                                                          NaN
# ...

# %%
# for i, x in enumerate(df_raw.safety_security2):
#     if type(x)==list:
#         if type(x[0]) == str:
#             df_raw.safety_security2[i][0] = df_raw.safety_security2[i][0].split(",")
#         df_raw.safety_security2[i] = list(set(tuple(l) for l in df_raw.safety_security2[i]))
#     else:
#         df_raw.safety_security2[i] = np.nan

# %%
df_raw["entertainment_media"].sample(3)
# Out:
# 8097     [Bluetooth, CD player, Hands-free equipment, On-board computer, Radio]
# 23485                                                                       NaN
# 29293                                     [CD player, On-board computer, Radio]
# Name: entertainment_media, dtype: object

# %%
df_raw["fuel consumption"][3]
# Out:
# nan

# %%
df_raw.extras
# Out:
# 0                                                                                  NaN
# 1                                                                                  NaN
# 2                                                                                  NaN
# 3                                                                        [Sport seats]
# 4                                                                                  NaN
#                                              ...
# 29475                                              [Alloy wheels (16"), Trailer hitch]
# 29476                   [Alloy wheels, Automatically dimming interior mirror, Spoiler]
# 29477                      [Alloy wheels (18"), Automatically dimming interior mirror]
# 29478    [Alloy wheels, Automatically dimming interior mirror, Ski bag, Trailer hitch]
# 29479                                                                              NaN
# Name: extras, Length: 29480, dtype: object

# %%
df_raw["full service history"].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
df_raw["full service history"]=df_raw["full service history"].apply(lambda x:0 if pd.isnull(x) else 1)

# %%
df_raw["full service history"]=df_raw["full service history"].astype(float)

# %%
df_raw["general inspection"].unique()
# Out:
# array([nan, 'New', '01/2024', '09/2022', '03/2024', '04/2023', '08/2024',
#        '07/2024', '09/2024', '06/2024', '02/2026', '05/2023', '01/2023',
#        '03/2023', '05/2026', '08/2023', '04/2024', '01/2025', '07/2023',
#        '06/2023', '12/2022', '11/2022', '02/2023', '09/2023', '11/2023',
#        '05/2024', '12/2023', '10/2023', '04/2022', '01/2022', '08/2025',
#        '05/2025', '05/2022', '02/2024', '10/2022', '04/2025', '06/2022',
#        '03/2025', '09/2025', '09/2020', '08/2022', '06/2020', '08/2021',
#        '07/2025', '10/2024', '02/2022', '12/2024', '07/2022', '06/2025',
#        '11/2024', '02/2025', '07/2021', '07/2020', '08/2018', '09/2021',
#        '10/2021', '03/2022', '12/2021', '08/2020', '05/2021', '10/2025',
#        '08/2013', '01/2021', '11/2021', '06/2021', '04/2026', '09/2017',
#        '07/2017', '06/2026', '12/2025', '09/2026', '01/2018', '11/2019',
#        '03/2026', '07/2026', '08/2026', '08/2019', '11/2020', '05/2020',
# ...

# %%
df_raw['general inspection'] = pd.to_datetime(df_raw['general inspection'], errors='coerce')

# %%
df_raw["general inspection"]=df_raw["general inspection"].dt.year
df_raw["general inspection"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 29475    2023.0
# 29476       NaN
# 29477       NaN
# 29478    2023.0
# 29479       NaN
# Name: general inspection, Length: 29480, dtype: float64

# %%
df_raw['last service'] = pd.to_datetime(df_raw['last service'], errors='coerce')

# %%
df_raw["last service"]=df_raw["last service"].dt.year

# %%
df_raw["last service"].unique()
# Out:
# array([  nan, 2022., 2021., 2020., 2018., 2016., 2017., 2019., 2013.,
#        2011., 1988., 2007., 2023., 2010., 2012.])

# %%
df_raw["non-smoker vehicle"].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
df_raw["colour"].unique()
# Out:
# array(['Black', nan, 'Grey', 'Yellow', 'White', 'Silver', 'Red', 'Blue',
#        'Green', 'Beige', 'Brown', 'Gold', 'Bronze', 'Violet', 'Orange'],
#       dtype=object)

# %%
# getting all the columns with string/mixed type values
#str_cols=list(df_raw.columns)
#str_cols.remove("production date")

# removing leading and trailing characters from columns with str type
#for i in str_cols:
#    df_raw[i] = df_raw[i].str.strip()

#This codes returns all the list in df_raw to NaN for some reason???

# %%
# to convert each list element to a string, and then apply the replace() and strip() methods to remove unwanted characters
#df_raw['model'] = df_raw['model'].apply(lambda x: ''.join(x)).str.replace(r'[\n, ]', '').str.strip()

#df_raw['model'] = df_raw['model'].str.strip('[]').str.replace(r'[\n, ]', '').str.strip()

# %%
#df_raw.Doors[0][0].split(",")[1]

# %%
#def clean_list(x):
#    if type(x)==list:
#        return x[0].split(",")[1]
#    else:
#       return np.nan

# %%
#df_raw.Doors.apply(clean_list).value_counts(dropna=False)

# %%
df1=df_raw

# %%
# !pip install skimpy
import skimpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rich
#     Found existing installation: rich 13.3.4
#     Uninstalling rich-13.3.4:
#       Successfully uninstalled rich-13.3.4
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
# ...

# %%
df1=skimpy.clean_columns(df1)
# Out:
# 31 column names have been cleaned

# %%
df1.T
# Out:
#                                        0                      1      \
# make_model               Mercedes-Benz A 160  Mercedes-Benz EQE 350
# short_description                        CDi                   350+
# make                           Mercedes-Benz          Mercedes-Benz
# model                                  A 160                EQE 350
# location                                  ES                     ES
# price_eur                              16950                  80900
# body_type                            Compact                Compact
# type                                    Used         Pre-registered
# doors                                      5                      4
# country_version                        Spain                  Spain
# offer_number                         7468157                7054863
# warranty_months                           24                     24
# mileage_km                            120200                   5000
# ...

# %%
df1["previous_owner"][1200][0]
# Out:
# ['34,438 km', '03/2020']

# %%
df1["previous_owner"][1200][1]
# Out:
# '1'

# %%
def clean_list_firstitem(x):
    if type(x)==list:
        return x[0][0].split(",")[0]
    else:
       return np.nan

# %%
def clean_list_2nditem(x):
    if type(x)==list:
        return x[0][1].split(",")[0]
    else:
       return np.nan

# %%
def clean_list_3rditem(x):
    if type(x)==list:
        return x[1]
    else:
       return np.nan

# %%
df1.previous_owner.apply(clean_list_firstitem).str.strip("/km ").value_counts(dropna=False)
# Out:
# NaN    15465
# 10       465
# 9        289
# 5        288
# 1        229
#        ...
# 520        1
# 530        1
# 262        1
# 570        1
# 301        1
# Name: previous_owner, Length: 380, dtype: int64

# %%
df1["previous_owner_km"]=df1.previous_owner.apply(clean_list_firstitem).str.strip("/km ")

# %%
df1["previous_owner_year"]=pd.to_datetime(df1.previous_owner.apply(clean_list_2nditem)).dt.year
df1["previous_owner_year"].value_counts(dropna=False)
# Out:
# NaN       15465
# 2019.0     2039
# 2022.0     1930
# 2021.0     1830
# 2018.0     1496
#           ...
# 1930.0        1
# 1960.0        1
# 1928.0        1
# 1956.0        1
# 1952.0        1
# Name: previous_owner_year, Length: 73, dtype: int64

# %%
df1["previous_owner_hand"]=df1.previous_owner.apply(clean_list_3rditem)

# %%
df1.extras.value_counts(dropna=False)
# Out:
# NaN                                                                                                                                                                                                                                                                   6000
# [Alloy wheels]                                                                                                                                                                                                                                                        3408
# [Alloy wheels, Roof rack]                                                                                                                                                                                                                                              380
# ...

# %%
#df1['extras'].apply(lambda x: sum(x) if isinstance(x, list) else np.nan)

# %%
def len_item_incol(x):
    if type(x)==list:
        return len(x[0].split(","))
    else:
       return np.nan

# %%
df1['extras'].apply(lambda x: len_item_incol(x))
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        1.0
# 4        NaN
#         ...
# 29475    2.0
# 29476    3.0
# 29477    2.0
# 29478    4.0
# 29479    NaN
# Name: extras, Length: 29480, dtype: float64

# %%
df1.extras[29478]
# Out:
# ['Alloy wheels, Automatically dimming interior mirror, Ski bag, Trailer hitch']

# %%
df1["extras"]=df1['extras'].apply(lambda x: len_item_incol(x))

# %%
df1.extras.unique()
# Out:
# array([nan,  1.,  7.,  2.,  3.,  5.,  6., 11.,  8.,  9., 10.,  4., 12.,
#        17., 13., 16., 15., 14., 19., 20., 18., 26.])

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %%
df1.isnull().sum()
# Out:
# make_model                  850
# short_description           850
# make                        850
# model                       850
# location                    850
#                           ...
# power_consumption_wltp    29464
# battery_ownership         29473
# previous_owner_km         15465
# previous_owner_year       15465
# previous_owner_hand       15465
# Length: 61, dtype: int64

# %%
df1.dropna(axis=1, thresh=5900, inplace=True) #dropped 17 columns where the null values were higher than %65

# %%
df1.make_model.isna().sum()
# Out:
# 850

# %%
df1.dropna(subset=['make_model'], inplace=True)

# %%
df1.make_model.isna().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# make_model                     0
# short_description              0
# make                           0
# model                          0
# location                       0
# price_eur                      0
# body_type                      0
# type                           0
# doors                        359
# country_version            11741
# offer_number                5530
# warranty_months            12979
# mileage_km                     1
# first_registration             2
# gearbox                      248
# fuel_type                   1787
# colour                      1724
# paint                      14135
# desc                         583
# seller                         0
# seats                       3125
# power_hp                     572
# engine_size_cc              1403
# gears                       9676
# co_emissions               10036
# manufacturer_colour         6843
# drivetrain                 11737
# cylinders                   9813
# ...

# %%
df1.warranty_months.unique()
# Out:
# array(['24', '12', nan, 'Yes', '48', '6', '3', '8', '36', '122', '60',
#        '22', '23', '18', '28', '17', '19', '21', '72', '11', '7', '1',
#        '10', '30', '13', '90', '16', '9', '84', '14', '15', '47', '20',
#        '27', '34', '33', '31', '26', '32', '99', '50', '35', '110', '142',
#        '80', '65', '43', '117', '58', '46', '2', '45', '53', '52', '39',
#        '25', '57', '37', '49', '55', '51', '29', '42', '44', '4'],
#       dtype=object)

# %%
df1["warranty_months"].replace("Yes", np.nan, inplace=True)

# %%
df1.warranty_months.isnull().sum()  # earlier 13826
# Out:
# 15298

# %%
df1.general_inspection.unique()
# Out:
# array([  nan, 2024., 2022., 2023., 2026., 2025., 2020., 2021., 2018.,
#        2013., 2017., 2019., 2027.])

# %%
df1.first_registration.isna().sum()
#fill the NaNa considering make model
# Out:
# 2

# %%
df1["first_registration"].fillna(df1.groupby(["make_model"])["first_registration"].transform(lambda x: x.mode().iloc[0]), inplace=True)

# %%
df1.first_registration.value_counts(dropna=False)
# Out:
# 2019.0    3668
# 2018.0    3492
# 2022.0    3086
# 2021.0    2871
# 2020.0    2473
#           ...
# 1929.0       1
# 1956.0       1
# 2202.0       1
# 1928.0       1
# 1950.0       1
# Name: first_registration, Length: 83, dtype: int64

# %%
df1["production_date"]=df_raw["production date"]

# %%
# Convert the column to datetime data type while handling NaN values
#df1['production_date'] = pd.to_datetime(df1['production_date'], errors='coerce')

# %%
df1['production_date'].astype(float)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 29474   NaN
# 29475   NaN
# 29476   NaN
# 29477   NaN
# 29478   NaN
# Name: production_date, Length: 28630, dtype: float64

# %%
df1.production_date.isna().sum()
# Out:
# 22722

# %%
df1["production_date"].fillna(df1.groupby(["make_model"])["first_registration"].transform(lambda x: x.mode().iloc[0]), inplace=True)

# %%
df1.production_date.value_counts(dropna=False)
# Out:
# 2018.0    5552
# 2019.0    4995
# 2022.0    4476
# 2021.0    3258
# 2020.0    2307
#           ...
# 1985.0       2
# 1958.0       2
# 1984.0       1
# 1961.0       1
# 1962.0       1
# Name: production_date, Length: 69, dtype: int64

# %%
df1["age"]=round((2022-df1['production_date']))

# %%
df1.age.isna().sum()
# Out:
# 0

# %%
df1[["make_model", "first_registration", "production_date", "age"]].sample(3)
# Out:
#           make_model  first_registration  production_date  age
# 9349     Peugeot 308              2019.0           2022.0  0.0
# 25550  Hyundai IONIQ              2017.0           2018.0  4.0
# 22867      Ford Kuga              2021.0           2020.0  2.0

# %%
#how to find elements in production_date column is different than the first_registration column

# %%
#df1.loc[df1["production_date"].isnull() & df1["first_registration"].notnull(), ["make_model", "production_date", "first_registration"]]

# %%
#df1.loc[df1["production_date"].notnull() != df1["first_registration"], ["make_model", "production_date", "first_registration"]]

# %%
#filling the NaNs in price column considering the model-make and age column

# %%
df1["price_eur"]=df1["price_eur"].astype(float)

# %%
df1.groupby(["make_model", "age"])["price_eur"].mean()
# Out:
# make_model    age
# Dacia         0.0     19144.000000
#               1.0     19515.000000
# Dacia Break   0.0     20500.000000
# Dacia Dokker  3.0     15980.000000
#               4.0     13158.618182
#                           ...
# Volvo XC90    3.0     54752.500000
#               4.0     45443.750000
#               5.0     48559.428571
#               6.0     38735.000000
#               10.0    29990.000000
# Name: price_eur, Length: 1695, dtype: float64

# %%
df1["trans_price_eur"] = df1.groupby(["make_model","age"])["price_eur"].transform("mean")

# %%
df1.loc[:,"price_eur"].fillna(df1['trans_price_eur'], inplace=True)

# %%
df1.price_eur.value_counts(dropna=False)
# Out:
# 14990.0    222
# 12990.0    219
# 16990.0    186
# 19990.0    166
# 9990.0     160
#           ...
# 19112.0      1
# 30465.0      1
# 18461.0      1
# 22649.0      1
# 4440.0       1
# Name: price_eur, Length: 5021, dtype: int64

# %%
df1["previous_owner_year"]=df1.loc[df1["age"]==0, "previous_owner_year"].fillna(method="ffill")
df1["previous_owner_year"].value_counts(dropna=False)
# Out:
# NaN       24188
# 2022.0     1890
# 2021.0      462
# 2020.0      395
# 2018.0      319
# 2017.0      292
# 2019.0      246
# 2016.0      197
# 2015.0      125
# 2014.0      120
# 2012.0      114
# 2013.0       96
# 2011.0       95
# 2010.0       28
# 2008.0       16
# 2009.0       10
# 1970.0        9
# 1968.0        8
# 1960.0        3
# 1966.0        3
# 2000.0        3
# 1975.0        2
# 1967.0        2
# 1953.0        2
# 2002.0        1
# 1997.0        1
# 2003.0        1
# 1900.0        1
# 1986.0        1
# Name: previous_owner_year, dtype: int64

# %%
df1["previous_owner_year"].fillna(df1.groupby(["make_model","age"])["first_registration"].transform(lambda x: x.mode().iloc[0]), inplace=True)
df1["previous_owner_year"].value_counts(dropna=False)
# Out:
# 2018.0    5894
# 2019.0    5247
# 2021.0    3662
# 2020.0    2692
# 2022.0    2007
#           ...
# 1953.0       2
# 1961.0       1
# 1984.0       1
# 1962.0       1
# 1900.0       1
# Name: previous_owner_year, Length: 72, dtype: int64

# %%
df1["mileage_km"].fillna(df1.groupby(["make_model","age"])["mileage_km"].transform(lambda x: x.mode().iloc[0]), inplace=True)

# %%
df1.mileage_km.value_counts(dropna=False)
# Out:
# 10        587
# 1         172
# 50        133
# 100       119
# 5000      118
#          ...
# 141589      1
# 59821       1
# 123500      1
# 29781       1
# 230047      1
# Name: mileage_km, Length: 14183, dtype: int64

# %%
df1["previous_owner_km"].fillna(df1.groupby(["make_model","age"])["mileage_km"].transform(lambda x: x.mode().iloc[0]), inplace=True)
df1["previous_owner_km"].value_counts(dropna=False)
# Out:
# 10        4414
# 129214     606
# 2          543
# 99311      450
# 1          392
#           ...
# 124989       1
# 227774       1
# 121004       1
# 135227       1
# 11600        1
# Name: previous_owner_km, Length: 1182, dtype: int64

# %%
df1["upholstery_colour"].fillna(df1["upholstery_colour"].mode()[0], inplace=True)
df1["upholstery_colour"].value_counts(dropna=False)
# Out:
# Black     24477
# Grey       2038
# Other      1003
# Beige       466
# Brown       275
# Red         159
# White        93
# Blue         82
# Orange       23
# Green         8
# Yellow        6
# Name: upholstery_colour, dtype: int64

# %%
df1["upholstery_colour"].mode()[0]
# Out:
# 'Black'

# %%
def fill_na_mode(col):
    return df1[col].fillna(df1[col].mode()[0], inplace=True)

# %%
def fill_na_mode_group(col):
    return df1[col].fillna(df1.groupby(["make_model"])[col].transform(lambda x: x.mode()[0] if x.notnull().any() else np.nan), inplace=True)

# %%
def fill_na_mode_group2(col):
    return df1[col].fillna(df1.groupby(["production_date"])[col].transform(lambda x: x.mode()[0] if x.notnull().any() else np.nan), inplace=True)

# %%
# def mode_filler(col):
#   for sub in df1.make_model.unique():  #sub will be unique values (.index may work too)
#   #print(i)
#     model = df1['make_model'] == sub
#     if df1[model][col].mode().iloc[0] != []:  #df1[model works like groupby]
#       df1.loc[model, col]  = df1.loc[model, col].fillna(df1[model][col].mode().iloc[0])
#     else :
#       df1.loc[model, col]  = df1.loc[model, col].fillna(df1[col].mode().iloc[0])

# %%
# def mode_filler2(col):
#   for sub in df1.make_model.unique():  #sub will be unique values (.index may work too)
#   #print(i)
#     model = df1['make_model'] == sub
#     if df1[model][col].mode().isna().any():  #df1[model works like groupby]
#       df1.loc[model, col]  = df1.loc[model, col].fillna(df1[col].mode(), inplace=True)
#     else:
#       df1.loc[model, col]  = df1.loc[model, col].fillna(df1[model][col].mode(), inplace=True)

# %%
#df1[df1['make_model']=='Dacia ']["doors"].mode().iloc[0] != []
# Out:
# True

# %%
fill_na_mode_group("upholstery")

# %%
fill_na_mode("upholstery")

# %%
df1["upholstery"].value_counts(dropna=False)
# Out:
# Cloth           15797
# Full leather     7644
# Part leather     3518
# alcantara         796
# Other             664
# Velour            211
# Name: upholstery, dtype: int64

# %%
fill_na_mode("manufacturer_colour")

# %%
#for i in df1.make_model.unique():
#  print(df1[df1.make_model == i]['manufacturer_colour'].mode()[0])

# %%
df1.doors.value_counts(dropna=False)
# Out:
# 5      17481
# 2       5523
# 4       3001
# 3       2259
# NaN      359
# 6          5
# 1          2
# Name: doors, dtype: int64

# %%
fill_na_mode_group("doors")

# %%
fill_na_mode("doors")

# %%
fill_na_mode_group("seats")

# %%
fill_na_mode("seats")

# %%
fill_na_mode_group("colour")

# %%
fill_na_mode("colour")

# %%
fill_na_mode_group("gearbox")

# %%
fill_na_mode("gearbox")

# %%
fill_na_mode("fuel_type")

# %%
df1.isna().sum()
# Out:
# make_model                     0
# short_description              0
# make                           0
# model                          0
# location                       0
# price_eur                      0
# body_type                      0
# type                           0
# doors                          0
# country_version            11741
# offer_number                5530
# warranty_months            15298
# mileage_km                     0
# first_registration             0
# gearbox                        0
# fuel_type                      0
# colour                         0
# paint                      14135
# desc                         583
# seller                         0
# seats                          0
# power_hp                     572
# engine_size_cc              1403
# gears                       9676
# co_emissions               10036
# manufacturer_colour            0
# drivetrain                 11737
# cylinders                   9813
# ...

# %%
def fill_na_mean(col):
    return df1[col].fillna(df1.groupby("make_model")[col].transform(lambda x: x.mean() if x.notnull().any() else np.nan), inplace=True)

# %%
def fill_na_mean2(col):
    return df1[col].fillna(df1.groupby("price_eur")[col].transform(lambda x: x.mean() if x.notnull().any() else np.nan), inplace=True)

# %%
df1.loc[df1["warranty_months"].isnull() & df1["make_model"].notnull(), ["make", "warranty_months"]].value_counts(dropna=False)
# Out:
# make           warranty_months
# Volvo          NaN                1849
# Renault        NaN                1485
# Ford           NaN                1341
# Opel           NaN                1327
# Mercedes-Benz  NaN                1259
# Peugeot        NaN                1259
# Fiat           NaN                1131
# Nissan         NaN                1063
# Hyundai        NaN                1027
# SEAT           NaN                1005
# Toyota         NaN                 988
# Skoda          NaN                 899
# Dacia          NaN                 665
# dtype: int64

# %%
df1.loc[df1["warranty_months"].notnull() & df1["make"].notnull(), ["make", "warranty_months"]]#.value_counts(dropna=False)
# Out:
#                 make warranty_months
# 0      Mercedes-Benz              24
# 1      Mercedes-Benz              24
# 2      Mercedes-Benz              12
# 3      Mercedes-Benz              12
# 4      Mercedes-Benz              12
# ...              ...             ...
# 29470          Volvo              12
# 29472          Volvo              12
# 29474          Volvo              12
# 29476          Volvo              13
# 29477          Volvo              12
#
# [13332 rows x 2 columns]

# %%
df1['warranty_months'] = df1['warranty_months'].replace('Yes', np.nan)

# %%
df1["warranty_months"] = df1["warranty_months"].astype(float)

# %%
fill_na_mean("warranty_months")

# %%
fill_na_mode("warranty_months")

# %%
df1.warranty_months.value_counts(dropna=False)
# Out:
# 12.000000     10905
# 24.000000      1546
# 60.000000      1018
# 8.520833        596
# 12.889286       583
#               ...
# 110.000000        1
# 117.000000        1
# 43.000000         1
# 65.000000         1
# 4.000000          1
# Name: warranty_months, Length: 238, dtype: int64

# %%
df1.warranty_months.isna().sum()
# Out:
# 0

# %%
df1["engine_size_cc"] = df1["engine_size_cc"].astype(float)

# %%
df1["gears"] = df1["gears"].astype(float)

# %%
df1["power_hp"] = df1["power_hp"].astype(float)

# %%
df1["cylinders"] = df1["cylinders"].astype(float)

# %%
df1["previous_owner_hand"]=df1["previous_owner_hand"].astype(float)

# %%
df1["empty_weight_kg"] = df1["empty_weight_kg"].astype(float)

# %%
fill_na_mean("power_hp")

# %%
fill_na_mean2("power_hp")

# %%
fill_na_mean("engine_size_cc")

# %%
fill_na_mean2("engine_size_cc")

# %%
fill_na_mode("engine_size_cc")

# %%
df1.engine_size_cc= df1.engine_size_cc.astype(float)

# %%
fill_na_mean("cylinders")

# %%
fill_na_mean2("cylinders")

# %%
fill_na_mode("cylinders")

# %%
df1.cylinders= df1.cylinders.astype(float)

# %%
fill_na_mean("gears")

# %%
fill_na_mean2("gears")

# %%
fill_na_mode("gears")

# %%
df1.gears= df1.gears.astype(float)

# %%
fill_na_mean("empty_weight_kg")

# %%
fill_na_mean2("empty_weight_kg")

# %%
fill_na_mode("empty_weight_kg")

# %%
df1.empty_weight_kg= df1.empty_weight_kg.astype(float)

# %%
fill_na_mode_group("previous_owner_hand")

# %%
fill_na_mode("previous_owner_hand")

# %%
df1.previous_owner_hand=df1.previous_owner_hand.astype(float)

# %%
df1[["co_emissions", "energy_efficiency_class", "co_efficiency"]].sample()
# Out:
#     co_emissions energy_efficiency_class co_efficiency
# 292          NaN                     NaN           NaN

# %%
df1.drop(["emission_class", "emissions_sticker"], axis=1, inplace=True)

# %%
df1.drop(["co_efficiency"], axis=1, inplace=True)

# %%
#def dropper(col):
#  df1 = df1.drop(col, axis = 1)

# %%
df1.drop(["offer_number", "paint","desc"], axis=1, inplace=True)

# %%
df1.drop(["model_code"], axis=1, inplace=True)

# %%
#df1.drop(["previous_owner"], axis=1, inplace=True)

# %%
#df1.non_smoker_vehicle =df1.non_smoker_vehicle.apply(lambda x: "0" if x == np.nan else x)

# %%
#df1.non_smoker_vehicle=df_original["Non-smoker vehicle"]

# %%
df1["non_smoker_vehicle"].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
df1.non_smoker_vehicle =df1.non_smoker_vehicle.apply(lambda x:0 if pd.isnull(x) else 1)

# %%
fill_na_mode("energy_efficiency_class")

# %%
fill_na_mode_group("drivetrain")

# %%
fill_na_mode("drivetrain")

# %%
#df1["drivetrain"].fillna(df1.groupby(["make_model"])["drivetrain"].transform(lambda x: x.mode().iloc[0]))

# %%
#df1.groupby(["make_model"])["drivetrain"].transform(lambda x: x.mode().iloc[0])

# %%
df1.drivetrain.unique()
# Out:
# array(['Front', '4WD', 'Rear'], dtype=object)

# %%
df1.extras
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        1.0
# 4        NaN
#         ...
# 29474    1.0
# 29475    2.0
# 29476    3.0
# 29477    2.0
# 29478    4.0
# Name: extras, Length: 28630, dtype: float64

# %%
fill_na_mode_group("extras")

# %%
fill_na_mode("extras")

# %%
fill_na_mode_group("country_version")
fill_na_mode_group2("country_version")
fill_na_mode("country_version")

# %%
fill_na_mode_group("general_inspection")
fill_na_mode_group2("general_inspection")
fill_na_mode("general_inspection")

# %%
df1.general_inspection=df1.general_inspection.astype(float)

# %%
df1["full_service_history"].replace("Yes", np.nan, inplace=True)

# %%
df1["full_service_history"]=df1["full_service_history"].astype(float)

# %%
fill_na_mode_group("full_service_history")

# %%
fill_na_mode("co_emissions")

# %%
df1 = df1.drop("previous_owner", axis=1)

# %%
#safety_security_dummies = df1['safety_security'].str.get_dummies(sep=', ')

# %%
df1.comfort_convenience
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                        NaN
# 1                                                                                                                                                                                                                                                                                                                                                        NaN
# ...

# %%
df1.safety_security
# Out:
# 0                                                                                                                                                                                                                                                                          NaN
# 1                                                                                                                                                                                                                                                                          NaN
# 2                                                                                                                                                                                                                                                                          NaN
# ...

# %%
#cond = (df["col1"]=="Merc") & (df["col2"]=="3")
#df.loc[cond, "var2"].fillna(df.loc[cond, "var2"].mode()[0])

# %%
#droping columns indicating repeating columns
#>>>> model
#>>>>

# %%
df1=df1.drop ("model", axis=1)

# %%
#df1=df1.drop("full_service_history", axis=1)

# %%
df1.short_description.unique()
# Out:
# array(['CDi', '350+', 'S 4Matic+ 8G-DCT', ...,
#        '1.6 D DRIVe Start/Stop R-design',
#        'T5 AUT(8) MOMENTUM BUSINESS SCHUIFDAK 360GR CAM LE',
#        '2.9 Executive G. NETTE AUTO! LEER! NAVI! CRUISE! L'], dtype=object)

# %%
df1.isna().sum()
# Out:
# make_model                    0
# short_description             0
# make                          0
# location                      0
# price_eur                     0
# body_type                     0
# type                          0
# doors                         0
# country_version               0
# warranty_months               0
# mileage_km                    0
# first_registration            0
# gearbox                       0
# fuel_type                     0
# colour                        0
# seller                        0
# seats                         0
# power_hp                      0
# engine_size_cc                0
# gears                         0
# co_emissions                  0
# manufacturer_colour           0
# drivetrain                    0
# cylinders                     0
# comfort_convenience        3197
# entertainment_media        4986
# safety_security            3215
# extras                        0
# empty_weight_kg               0
# ...

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %%
#df2 = df1.select_dtypes(include = ['float64', 'int64'])

# %%
from scipy.stats.mstats import winsorize

# %%
df1.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'location', 'price_eur',
#        'body_type', 'type', 'doors', 'country_version', 'warranty_months',
#        'mileage_km', 'first_registration', 'gearbox', 'fuel_type', 'colour',
#        'seller', 'seats', 'power_hp', 'engine_size_cc', 'gears',
#        'co_emissions', 'manufacturer_colour', 'drivetrain', 'cylinders',
#        'comfort_convenience', 'entertainment_media', 'safety_security',
#        'extras', 'empty_weight_kg', 'general_inspection',
#        'full_service_history', 'non_smoker_vehicle', 'upholstery_colour',
#        'upholstery', 'production_date', 'energy_efficiency_class',
#        'previous_owner_km', 'previous_owner_year', 'previous_owner_hand',
#        'age', 'trans_price_eur'],
#       dtype='object')

# %%
df1.corr()
# Out:
#                       price_eur  warranty_months  first_registration  \
# price_eur              1.000000         0.091243            0.152717
# warranty_months        0.091243         1.000000            0.213391
# first_registration     0.152717         0.213391            1.000000
# power_hp               0.606484         0.020488            0.026897
# engine_size_cc         0.278036        -0.044150           -0.183781
# gears                  0.273517         0.023746            0.203931
# cylinders              0.358117        -0.077356           -0.255055
# extras                 0.241803         0.243378            0.209280
# empty_weight_kg        0.448082         0.048328            0.095799
# general_inspection     0.156801         0.196458            0.276829
# full_service_history   0.120822         0.190381            0.130789
# non_smoker_vehicle     0.128392         0.211427            0.105915
# production_date        0.066045         0.209151            0.792297
# ...

# %%
df1.describe().T
# Out:
#                         count          mean           std     min  \
# price_eur             28630.0  23555.202131  25953.706540   490.0
# warranty_months       28630.0     17.538924     11.521037     1.0
# first_registration    28630.0   2015.163290      8.757677  1900.0
# power_hp              28630.0    162.744618     92.838925     1.0
# engine_size_cc        28630.0   1745.062836   1038.592153     0.0
# gears                 28630.0      5.882950      1.432352     0.0
# cylinders             28630.0      4.045943      0.993720     1.0
# extras                28630.0      4.346280      3.621809     1.0
# empty_weight_kg       28630.0   1421.767177    317.326925    75.0
# general_inspection    28630.0   2023.435417      0.759448  2013.0
# full_service_history  28630.0      0.438875      0.496258     0.0
# non_smoker_vehicle    28630.0      0.404960      0.490893     0.0
# production_date       28630.0   2016.379183      8.217726  1929.0
# ...

# %%
plt.figure(figsize = (15, 8))
sns.boxplot(x = df1['price_eur']);

# %%
plt.figure(figsize = (15, 8))
sns.displot(df1.price_eur, kind="hist", bins = 10);

# %%
Q1 = df1["price_eur"].quantile(0.25)
Q3 = df1["price_eur"].quantile(0.75)

IQR = Q3 - Q1

# %%
print(Q1)
print(Q3)
print(IQR)
# Out:
# 11990.0
# 27990.0
# 16000.0

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
(df1.price_eur < lower_lim).value_counts()
# Out:
# False    28630
# Name: price_eur, dtype: int64

# %%
(df1.price_eur > upper_lim).value_counts()
# Out:
# False    26720
# True      1910
# Name: price_eur, dtype: int64

# %%
df1.price_eur.describe()
# Out:
# count    2.863000e+04
# mean     2.355520e+04
# std      2.595371e+04
# min      4.900000e+02
# 25%      1.199000e+04
# 50%      1.798000e+04
# 75%      2.799000e+04
# max      1.346900e+06
# Name: price_eur, dtype: float64

# %%
not_outliers = (df1.price_eur >= lower_lim) & (df1.price_eur <= upper_lim)

# %%
len(df1[not_outliers])
# Out:
# 26720

# %%
cleaned_df1=df1[not_outliers]
cleaned_df1

# %%
cleaned_df1.shape
# Out:
# (26720, 41)

# %%
cleaned_df1.price_eur.describe()
# Out:
# count    26720.000000
# mean     19221.734281
# std      10837.292263
# min        490.000000
# 25%      11570.250000
# 50%      16990.000000
# 75%      25650.000000
# max      51990.000000
# Name: price_eur, dtype: float64

# %%
plt.figure(figsize = (15, 8))

sns.boxplot(x = cleaned_df1.price_eur);

# %%
plt.figure(figsize = (15, 8))
sns.boxplot(x = cleaned_df1['engine_size_cc']);

# %%
Q1 = df1["engine_size_cc"].quantile(0.25)
Q3 = df1["engine_size_cc"].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
a = len(cleaned_df1.engine_size_cc[cleaned_df1.engine_size_cc < lower_lim]) / len(cleaned_df1)
a
# Out:
# 0.012574850299401197

# %%
cleaned_df1.engine_size_cc.quantile(a)
# Out:
# 495.912574850297

# %%
b = len(cleaned_df1.engine_size_cc[cleaned_df1.engine_size_cc > upper_lim]) / len(cleaned_df1)
b
# Out:
# 0.04307634730538922

# %%
cleaned_df1.engine_size_cc.quantile(1-b)
# Out:
# 2965.1277580708143

# %%
upper_lim
# Out:
# 2966.5

# %%
lower_lim
# Out:
# 346.5

# %%
engine_size_win = winsorize(cleaned_df1.engine_size_cc, (a, b))  # using percents derived from IQR "fences"
engine_size_win
# Out:
# masked_array(data=[1514.92857143, 1991.        , 2143.        , ...,
#                    1560.        , 1969.        , 2922.        ],
#              mask=False,
#        fill_value=1e+20)

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(x=engine_size_win);

# %%
Q1 = df1["gears"].quantile(0.25)
Q3 = df1["gears"].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
(cleaned_df1.gears < lower_lim).value_counts()
# Out:
# False    25691
# True      1029
# Name: gears, dtype: int64

# %%
(cleaned_df1.gears > upper_lim).value_counts()
# Out:
# False    26093
# True       627
# Name: gears, dtype: int64

# %%
cleaned_df1.gears.describe()
# Out:
# count    26720.000000
# mean         5.792243
# std          1.325879
# min          0.000000
# 25%          5.000000
# 50%          6.000000
# 75%          6.092827
# max         10.000000
# Name: gears, dtype: float64

# %%
not_outliers_gears = (cleaned_df1.gears >= lower_lim) & (cleaned_df1.gears <= upper_lim)

# %%
len(cleaned_df1[not_outliers_gears])
# Out:
# 25064

# %%
cleaned_df2=cleaned_df1[not_outliers_gears]

# %%
plt.figure(figsize = (15, 8))
sns.boxplot(x = cleaned_df2['gears']);

# %%
Q1 = df1["cylinders"].quantile(0.25)
Q3 = df1["cylinders"].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
a = len(cleaned_df2.cylinders[cleaned_df2.cylinders < lower_lim]) / len(cleaned_df2)
a
# Out:
# 0.21951803383338653

# %%
cleaned_df2.cylinders.quantile(a)
# Out:
# 3.5695241183651776

# %%
b = len(cleaned_df2.cylinders[cleaned_df2.cylinders > upper_lim]) / len(cleaned_df2)
b
# Out:
# 0.09264283434407916

# %%
cleaned_df2.cylinders.quantile(1-b)
# Out:
# 4.2464347547335315

# %%
upper_lim
# Out:
# 4.260142619772916

# %%
lower_lim
# Out:
# 3.5664289670451397

# %%
cylinders_win = winsorize(cleaned_df2.cylinders, (a, b))  # using percents derived from IQR "fences"
cylinders_win
# Out:
# masked_array(data=[4.        , 4.        , 4.        , ..., 4.        ,
#                    4.        , 4.24242424],
#              mask=False,
#        fill_value=1e+20)

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(x=cylinders_win);

# %%
not_outliers_cylinders = (cleaned_df2.cylinders >= lower_lim) & (cleaned_df2.cylinders <= upper_lim)

# %%
cleaned_df3=cleaned_df2[not_outliers_cylinders]

# %%
df_final = cleaned_df3.drop(["short_description", "type", "country_version", "make", "seller", "production_date", "manufacturer_colour", "comfort_convenience", "safety_security", "previous_owner_year", "previous_owner_km", "trans_price_eur"], axis=1)
df_final
# Out:
#                    make_model location  price_eur body_type doors  \
# 0         Mercedes-Benz A 160       ES    16950.0   Compact     5
# 3      Mercedes-Benz A 35 AMG       ES    46990.0   Compact     5
# 4      Mercedes-Benz A 45 AMG       ES    16800.0   Compact     5
# 5         Mercedes-Benz C 160       DE     4690.0   Compact     3
# 6       Mercedes-Benz CLA 180       ES    22550.0   Compact     5
# ...                       ...      ...        ...       ...   ...
# 29470               Volvo S90       ES    27190.0     Sedan     4
# 29471               Volvo V40       BE    13000.0     Sedan     5
# 29474               Volvo S90       ES    37600.0     Sedan     4
# 29476               Volvo C30       BE     7300.0     Sedan     3
# 29477               Volvo S90       NL    29900.0     Sedan     4
#
#        warranty_months mileage_km  first_registration    gearbox fuel_type  \
# 0            24.000000     120200              2016.0     Manual    diesel
# ...

# %%
#selected columns
df_final1=df_final[["location","non_smoker_vehicle", "drivetrain", "upholstery", "fuel_type", "engine_size_cc", "make_model", "price_eur", "body_type", "seats", "doors", "warranty_months", "mileage_km", "empty_weight_kg", "age", "previous_owner_hand", "energy_efficiency_class", "power_hp", "gears", "extras"]]

# %%
#selected columns2
df_final2=df_final[["location", "non_smoker_vehicle","upholstery", "drivetrain", "fuel_type", "engine_size_cc", "make_model", "price_eur", "body_type", "seats", "doors", "warranty_months", "mileage_km", "empty_weight_kg", "age", "previous_owner_hand", "energy_efficiency_class", "power_hp", "gears"]]

# %%
#selected numerical columns for pairplot
df_final_num=df_final[["price_eur", "warranty_months", "mileage_km", "age"]]

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %%
df_final.drivetrain.unique()
# Out:
# array(['Front', '4WD', 'Rear'], dtype=object)

# %%
df_final.fuel_type.unique()
# Out:
# array(['diesel', 'gasoline', 'LPG', 'LPG_and_gasoline', 'others',
#        'Ethanol', 'CNG', 'electric'], dtype=object)

# %%
df_final["make_model_volvo]"]=df_final[df_final.make_model.str.contains("Volvo")].make_model

# %%
sns.catplot(x='drivetrain', y = "price_eur", data=df_final2, kind="bar",  height=3, aspect=1);

# %%
sns.catplot(x='fuel_type', y = "price_eur", data=df_final2, kind="bar",  height=5, aspect=2);

# %%
sns.catplot(x='energy_efficiency_class',
            # y = "survived",
            data=df_final1,
            kind="count",
            # estimator=np.count_nonzero,
            errorbar=None,)
            #hue="body_type");
            #row="drivetrain",
            #col="price_eur");

# %%
sns.catplot(x='drivetrain',
            y = "price_eur",
            data=df_final1,
            kind="bar",
            # estimator=np.count_nonzero,
            errorbar=None,
            hue="body_type")
            #row="drivetrain",
            #col="price_eur");

# %%
# sns.catplot(x='make_model_volvo]',
#             y = "price_eur",
#             data=df_final,
#             kind="bar",
#             # estimator=np.count_nonzero,
#             errorbar=None)
#             #hue="drivetrain")
#             #row="drivetrain",
#             #col="price_eur");

# %%
#sns.pairplot(df_final_num, palette='viridis', corner=True, diag_kind='auto')

# %%
sns.catplot(x='drivetrain',
            y = "price_eur",
            data=df_final2,
            kind="bar",
            # estimator=np.count_nonzero,
            errorbar=None,
            hue="non_smoker_vehicle",
            col="upholstery");
            #row="alone",)

# %%
df_final2.make_model.sort_values(ascending=False)
# Out:
# 27526      Volvo XC90
# 27867      Volvo XC90
# 27873      Volvo XC90
# 27882      Volvo XC90
# 27883      Volvo XC90
#              ...
# 16389    Dacia Dokker
# 16223    Dacia Dokker
# 16318    Dacia Dokker
# 16536     Dacia Break
# 16846          Dacia
# Name: make_model, Length: 17240, dtype: object

# %%
sns.catplot(x="drivetrain", y='price_eur', data=df_final2, kind="box");

# %%
sns.catplot(x="fuel_type", y='price_eur', data=df_final2, kind="box", aspect=3);

# %%
sns.catplot(x="upholstery", y='price_eur', data=df_final2, kind="box", hue="non_smoker_vehicle", aspect=2);

# %%
#sns.swarmplot(x="age", y='price_eur', data=df_final2);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-463-292e561cbb98> in <cell line: 1>()
# ----> 1 sns.swarmplot(x="age", y='price_eur', data=df_final2);
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2662     ))
#    2663
# -> 2664     p.plot_swarms(
#    2665         dodge=dodge,
#    2666         color=color,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in plot_swarms(self, dodge, color, edgecolor, warn_thresh, plot_kws)
#     397                 points.draw = draw.__get__(points)
#     398
# --> 399         _draw_figure(ax.figure)
#     400
#     401         # Finalize the axes details
#
# ...

# %%
sns.heatmap(data=df_final2.corr(), cmap='magma', annot=True, center=0);

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
#df.to_csv("final_scout_not_dummy.csv", index=False)

# %%
df_final.to_csv("final_edafile.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %%
df_dummy = pd.get_dummies(data = df_final2, drop_first=False)
df_dummy
# Out:
#        engine_size_cc  price_eur  warranty_months  empty_weight_kg   age  \
# 0         1514.928571    16950.0        24.000000      1270.625000   6.0
# 3         1991.000000    46990.0        12.000000      1516.000000   3.0
# 4         2143.000000    16800.0        12.000000      1545.000000   2.0
# 5         1799.000000     4690.0        18.000000      1465.000000   3.0
# 6         1503.521739    22550.0        12.000000      1416.785714   4.0
# ...               ...        ...              ...              ...   ...
# 29470     1969.000000    27190.0        12.000000      1683.000000   1.0
# 29471     1969.000000    13000.0        12.119427      1532.000000   4.0
# 29474     1969.000000    37600.0        12.000000      2077.000000   1.0
# 29476     1560.000000     7300.0        13.000000      1356.000000  15.0
# 29477     1969.000000    29900.0        12.000000      1617.000000   1.0
#
#        previous_owner_hand    power_hp     gears  location_ AT  location_ BE  \
# ...

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
#df_dummied.to_csv("final_scout_dummy.csv", index=False)

# %%
df_dummy.to_csv("final_edafile_dummy.csv", index=False)
